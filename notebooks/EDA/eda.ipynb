# %%
import pandas as pd
import numpy as np

import os

# %% [markdown]
# # Distributions

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(os.getcwd() + '\\..\\..\\data\\cleaned\\FinalPlanetarySystem.csv')
df.head()
# Out:
#    PlanetName  HostName PlanetLetter  NumberOfStars  NumberOfPlanets  \
# 0    51 Eri b    51 Eri            b              3                1
# 1    55 Cnc b    55 Cnc            b              2                5
# 2   CoRoT-1 b   CoRoT-1            b              1                1
# 3  CoRoT-10 b  CoRoT-10            b              1                1
# 4  CoRoT-11 b  CoRoT-11            b              1                1
#
#    NumberOfMoons  DiscoveryYear  OrbitalPeriod  OrbitSemiMajorAxis  \
# 0              0           2015   11688.000000            13.20000
# 1              0           1996      14.651600             0.11340
# 2              0           2008       1.508956             0.02752
# 3              0           2010      13.240600             0.10550
# 4              0           2010       2.994330             0.04360
#
#    PlanetEarthRadius  ...  TotalProperMotion  ProperMotion(RA)  \
# 0              13.40  ...          77.728795          44.35230
# ...

# %%
df.columns
# Out:
# Index(['PlanetName', 'HostName', 'PlanetLetter', 'NumberOfStars',
#        'NumberOfPlanets', 'NumberOfMoons', 'DiscoveryYear', 'OrbitalPeriod',
#        'OrbitSemiMajorAxis', 'PlanetEarthRadius', 'PlanetJupiterRadius',
#        'PlanetEarthMass', 'PlanetJupiterMass', 'PlanetProvenance',
#        'PlanetDensity', 'PlanetEquilibriumTemperature',
#        'StellarEffectiveTemperature', 'StellarRadius', 'StellarMass',
#        'StellarMetallicity', 'StellarMetallicityRatio', 'StellarLuminosity',
#        'StellarSurfaceGravity', 'StellarAge', 'StellarDensity',
#        'RA[sexagesimal]', 'RA[deg]', 'Dec[sexagesimal]', 'Dec[deg]',
#        'GalacticLatitude', 'GalacticLongitude', 'EclipticLatitude',
#        'EclipticLongitude', 'TotalProperMotion', 'ProperMotion(RA)',
#        'ProperMotion(Dec)', 'Distance', 'Parallax', 'PlanetType',
#        'PlanetEccentricity', 'PerihelionDistance', 'AphelionDistance',
#        'PotentiallyHabitable'],
#       dtype='object')

# %% [markdown]
# ## What is the Distribution of NumberOfStars in the Planetary System?

# %%
def plot(df, kind)

# %%
# With the Planetary Systems, How many are discovered from the start to now?

plt.figure(figsize=(8,5))
plt.bar(df['NumberOfStars'].unique(), df['NumberOfStars'].value_counts())
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.bar(df['NumberOfPlanets'].unique(), df['NumberOfPlanets'].value_counts())
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['OrbitalPeriod'])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['PlanetEarthRadius'])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['PlanetEarthMass'])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['PlanetDensity'])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['PlanetEquilibriumTemperature'])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['StellarEffectiveTemperature'])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['StellarRadius'])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['StellarMass'])
plt.show()

# %%
# StellarMetallicity - Knowing the Components of the Star

plt.figure(figsize=(8,5))
sns.kdeplot(df['StellarMetallicity'])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['StellarLuminosity'])
plt.show()
